# %% [markdown]
# ---
# layout: post
# title: Data Structures Writeup
# type: plans
# courses: { compsci: {week: 4} }
# ---

# %% [markdown]
# **Collections** <br>
# Blog Python Model code and SQLite Database.
#
# [![image.png](https://i.postimg.cc/y6h8hNSh/image.png)](https://postimg.cc/K4zbxxf4)
# We initiated a SQLite Database with a Model file called ML. This database includes social class, age, sex, siblings, family, fare, port, alone. Using this database, we can then store the data of users and calculate the end value.
#
# From VSCode using SQLite3 Editor, show your unique collection/table in database, display rows and columns in the table of the SQLite database.
#
# [![image.png](https://i.postimg.cc/5NHkdXqL/image.png)](https://postimg.cc/Tp6cnYs3)
# This is a picture of my data from my CPT, which contains various data for each college, to be used in the frontend for search.
#
# From VSCode model, show your unique code that was created to initialize table and create test data.
#
# [![image.png](https://i.postimg.cc/WbPSK5zL/image.png)](https://postimg.cc/s1wpG95w)
# We didn't use test data, because all the data in the table was from an API that I cleaned and inserted. This code shows the initialization of the database.
#
# **Lists and Dictionaries** <br>
# Blog Python API code and use of List and Dictionaries.
#
# [![image.png](https://i.postimg.cc/MGh1BGj2/image.png)](https://postimg.cc/1grghsHJ)
# This is the dictionary containing every passenger that is inputted and used to calculate our output.
#
# In VSCode using Debugger, show a list as extracted from database as Python objects.
#
# [![image.png](https://i.postimg.cc/1zxzcVMH/image.png)](https://postimg.cc/K1NFmz6k)
# This image shows the attribute values of an example passenger dictionary.
#
# **APIs and JSON** <br>
# Blog Python API code and use of Postman to request and respond with JSON.
#
# In VSCode, show Python API code definition for request and response using GET, POST, UPDATE methods. Discuss algorithmic condition used to direct request to appropriate Python method based on request method.
#
# [![image.png](https://i.postimg.cc/dtrQQVJZ/image.png)](https://postimg.cc/GH3nqr8b)
# This is the GET and POST request of my API, although only the GET request is really used in the data table. This is because the data was already cleaned and placed in, and all the API needs to do is to transmit the data to the frontend.
#
# In VSCode, show algorithmic conditions used to validate data on a POST condition.
#
# [![image.png](https://i.postimg.cc/HnGGFbcZ/image.png)](https://postimg.cc/ygTrZgTc)
# This code uses the parser and add_argument to find if the required attributes are in the correct data type and appends it to the Data class. It also uses a try except to confirm that there are no other errors.
#
# In Postman, show URL request and Body requirements for GET, POST, and UPDATE methods.
#
# [![image.png](https://i.postimg.cc/zXJ2vdrw/image.png)](https://postimg.cc/qg5xZxgg)
# This database only uses the GET method, and the URL is localhost:8199/dataList. DataList will GET a list of all available data in the database.
#
# In Postman, show the JSON response data for 200 success conditions on GET, POST, and UPDATE methods.
#
# [![image.png](https://i.postimg.cc/j28HL4Hv/image.png)](https://postimg.cc/hQdzYx37)
# This shows the 200 success code with using the GET method.
#
# In Postman, show the JSON response for error for 400 when missing body on a POST request.
#
# [![image.png](https://i.postimg.cc/FRN3pBGD/image.png)](https://postimg.cc/cKkv4Tpn)
# This is the JSON response with a POST request has a missing body.
#
# **Frontend** <br>
# Blog JavaScript API fetch code and formatting code to display JSON.
#
# [![image.png](https://i.postimg.cc/9FnkkG6G/image.png)](https://postimg.cc/kBWw6tX4)
# This is the frontend fetch code. This goes to the URL and gets data from dataList, then updates it to the viewing service our program offers.
#
# In Chrome inspect, show response of JSON objects from fetch of GET, POST, and UPDATE methods.
#
# [![image.png](https://i.postimg.cc/3RNpzv5v/image.png)](https://postimg.cc/34MdvWw8)
# This shows the online JSON objects in the debugger that shows the response.
#
# In the Chrome browser, show a demo (GET) of obtaining an Array of JSON objects that are formatted into the browsers screen.
# In JavaScript code, describe fetch and method that obtained the Array of JSON objects.
# In JavaScript code, show code that performs iteration and formatting of data into HTML.
#
# [![image.png](https://i.postimg.cc/YSGL3w16/image.png)](https://postimg.cc/kVC5JzYG)
# This organizes the objects that is retrieved from the backend into the list tr for each row of data using iteration.
#
# In JavaScript code, show and describe code that handles success. Describe how code shows success to the user in the Chrome Browser screen.
#
# [![image.png](https://i.postimg.cc/B6CS5hw5/image.png)](https://postimg.cc/VrdPmFw5)
# If you survive covid based on the inputted titanic data, the data will show that it is received and returns the calculated vaccination rate.
#
# In JavaScript code, show and describe code that handles failure. Describe how the code shows failure to the user in the Chrome Browser screen.
#
# [![image.png](https://i.postimg.cc/nrsWVr7s/image.png)](https://postimg.cc/Fk4pD9Tm)
# If there is an error, there will be no calculated value that is returned.
